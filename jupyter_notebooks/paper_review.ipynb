# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# $X \in \mathbb{R}^{100 \times 40}$
#
# where
#
# $100$ is the **lookback** period (time series lag)
#
# $4 \times 10 = 40$ is the number of features where each $4$ feature group consists of *price_ask, volume_ask, price_bid, volume_bid* at each level of orderbook, $10$ levels total.

# %% [markdown]
# ## Calculating *current* mid price
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ## Calculating *past* and *future* mid prices
#
# ![image-5.png](attachment:image-5.png)
#
# ## Calculating *percentage returns*
#
# ![image.png](attachment:image.png)
